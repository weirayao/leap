# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
datum = np.load("/home/cmu_wyao/projects/data/24.npz")

# %%
plt.plot(datum["x"][0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f0651ec9a50>,
#  <matplotlib.lines.Line2D at 0x7f0651ec9650>,
#  <matplotlib.lines.Line2D at 0x7f0605b85a50>,
#  <matplotlib.lines.Line2D at 0x7f0605b85a90>]

# %%
ma = [ ]
mi = [ ]
for i in range(1000):
    datum = np.load("/home/cmu_wyao/projects/data/%d.npz"%i)
    ma.append(datum["x"].max(axis=0).max(axis=0))
    mi.append(datum["x"].min(axis=0).min(axis=0))

# %%
np.stack(ma).max(axis=0)
# Out:
# array([591.5796 , 496.26367,  50.26638, 143.61914], dtype=float32)

# %%
np.stack(mi).min(axis=0)
# Out:
# array([-78.12708  ,  -1.7142837, -19.542505 , -22.891457 ], dtype=float32)
